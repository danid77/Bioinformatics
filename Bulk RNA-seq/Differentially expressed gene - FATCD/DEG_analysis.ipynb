# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
CD_Con = pd.read_csv('CD_Con.txt', sep=',', engine='python', encoding='cp949')
CrF_Con = pd.read_csv('CrF_Con.txt', sep=',', engine='python', encoding='cp949')
CrF_CD = pd.read_csv('CrF_CD.txt', sep=',', engine='python', encoding='cp949')

display(CD_Con)
display(CrF_Con)
display(CrF_CD)
# Out:
#                          Unnamed: 0     baseMean  log2FoldChange     lfcSE  \
# 0      ENSG00000237491.10_LINC01409   171.584893       -0.215632  0.302521
# 1          ENSG00000177757.2_FAM87B    75.323918       -0.207557  0.435445
# 2      ENSG00000228794.10_LINC01128  1071.957048       -0.514346  0.183977
# 3         ENSG00000187634.13_SAMD11   107.906264       -0.922050  0.442539
# 4          ENSG00000188976.11_NOC2L   650.471727        0.069691  0.146395
# ...                             ...          ...             ...       ...
# 17263     ENSG00000212907.2_MT-ND4L   432.764866       -0.317473  0.236880
# 17264      ENSG00000198886.2_MT-ND4  1705.550426       -0.400741  0.166924
# 17265      ENSG00000198786.2_MT-ND5  1667.546508       -0.503011  0.160014
# 17266      ENSG00000198695.2_MT-ND6   126.476279       -0.510547  0.224731
# 17267      ENSG00000198727.2_MT-CYB  3868.999654       -0.287480  0.196699
#
#            stat    pvalue      padj
# ...

# %%
CD_Con_list = CD_Con['Unnamed: 0'].str.split('_')
CrF_Con_list = CrF_Con['Unnamed: 0'].str.split('_')
CrF_CD_list = CrF_CD['Unnamed: 0'].str.split('_')

# %%
CD_Con['gene'] = CD_Con_list.str.get(1)
CrF_Con['gene'] = CrF_Con_list.str.get(1)
CrF_CD['gene'] = CrF_CD_list.str.get(1)

# %%
CrF_CD.columns
# Out:
# Index(['Unnamed: 0', 'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue',
#        'padj', 'gene'],
#       dtype='object')

# %%
CD_Con = CD_Con[['gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj']]
CrF_Con = CrF_Con[['gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj']]
CrF_CD = CrF_CD[['gene', 'baseMean', 'log2FoldChange', 'lfcSE', 'stat', 'pvalue', 'padj']]

# %%
display(CD_Con)
display(CrF_Con)
display(CrF_CD)
# Out:
#             gene     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 0      LINC01409   171.584893       -0.215632  0.302521 -0.712785  0.475979
# 1         FAM87B    75.323918       -0.207557  0.435445 -0.476654  0.633608
# 2      LINC01128  1071.957048       -0.514346  0.183977 -2.795705  0.005179
# 3         SAMD11   107.906264       -0.922050  0.442539 -2.083545  0.037202
# 4          NOC2L   650.471727        0.069691  0.146395  0.476048  0.634040
# ...          ...          ...             ...       ...       ...       ...
# 17263    MT-ND4L   432.764866       -0.317473  0.236880 -1.340223  0.180173
# 17264     MT-ND4  1705.550426       -0.400741  0.166924 -2.400740  0.016362
# 17265     MT-ND5  1667.546508       -0.503011  0.160014 -3.143536  0.001669
# 17266     MT-ND6   126.476279       -0.510547  0.224731 -2.271811  0.023098
# 17267     MT-CYB  3868.999654       -0.287480  0.196699 -1.461519  0.143873
#
#            padj
# 0      0.720743
# 1      0.821876
# ...

# %%
CD_Con_deg = CD_Con[(CD_Con['padj'] < 0.05) & (abs(CD_Con['log2FoldChange']) > 1.5)]
CrF_Con_deg = CrF_Con[(CrF_Con['padj'] < 0.05) & (abs(CrF_Con['log2FoldChange']) > 1.5)]
CrF_CD_deg = CrF_CD[(CrF_CD['padj'] < 0.05) & (abs(CrF_CD['log2FoldChange']) > 1.5)]

display(CD_Con_deg)
display(CrF_Con_deg)
display(CrF_CD_deg)
# Out:
#             gene    baseMean  log2FoldChange     lfcSE      stat  \
# 211      PLA2G2A  866.446798       -2.024622  0.536704 -3.772324
# 224        KIF17  110.263243        1.730023  0.372226  4.647780
# 632        HOOK1  181.203008       -1.861200  0.526293 -3.536433
# 892       TMIGD3  188.786092        1.882038  0.616226  3.054136
# 921        AMPD1  142.550962        3.873401  0.685011  5.654507
# ...          ...         ...             ...       ...       ...
# 16681      CXADR  202.719331       -2.681229  0.776112 -3.454691
# 16718      GRIK1  169.555954        1.521035  0.336923  4.514487
# 16799    UBASH3A  107.807700        1.524611  0.521420  2.923958
# 16827  ITGB2-AS1   59.035776        1.709851  0.566935  3.015954
# 16931      DERL3   67.764247        3.950486  0.840560  4.699826
#
#              pvalue      padj
# 211    1.617339e-04  0.004326
# 224    3.355261e-06  0.000285
# 632    4.055691e-04  0.008220
# 892    2.257100e-03  0.026354
# ...

# %%
CD_Con_set = set(CD_Con_deg['gene']) # 130
CrF_Con_set = set(CrF_Con_deg['gene']) # 463
CrF_CD_set = set(CrF_CD_deg['gene']) # 101

# %%
print(list(CrF_CD_set & CD_Con_set)) # 101 & 130
print(len(CrF_CD_set & CD_Con_set)) # => 26
print(CrF_Con_set & CD_Con_set) # 463 & 130
print(len(CrF_Con_set & CD_Con_set)) # => 80
print(CrF_CD_set & CrF_Con_set) # 101 & 463
print(len(CrF_CD_set & CrF_Con_set)) # => 75
# Out:
# ['BHLHA15', 'DERL3', 'KRT19', 'SDC1', 'BICDL1', 'DSC3', 'AMPD1', 'MZB1', 'HOOK1', 'IFNG-AS1', 'SLAMF7', 'JCHAIN', 'CDH1', 'HLA-DOB', 'ITLN1', 'ALOX15', 'FCRL2', 'BNC1', 'FCRL5', 'ASPM', 'FAM110C', 'LINC02362', 'JSRP1', 'TNFRSF17', 'MYRF', 'POU2AF1']
# 26
# ...

# %%
print(CD_Con_set - CrF_CD_set)
print(len(CD_Con_set - CrF_CD_set))
print(CrF_CD_set - CD_Con_set)
print(len(CrF_CD_set - CD_Con_set))
# Out:
# {'ARHGDIG', 'CDCP1', 'IGF2BP3', 'UPK1B', 'AADAC', 'GRIA1', 'SCEL', 'CCL3', 'NQO1', 'RARRES1', 'TMIGD3', 'KRT8', 'LUZP2', 'TGM1', 'GRIK1', 'ITGB2-AS1', 'ADAMTS14', 'CNTN3', 'ALPK2', 'DNAJC5B', 'HHIP', 'KIF19', 'TIMD4', 'CRYAB', 'APOE', 'PI15', 'FAT2', 'TMEM196', 'FGF1', 'LGI1', 'CXADR', 'SLPI', 'COBL', 'DEFB132', 'SPP1', 'SERTM1', 'GJC3', 'CTD-3247F14.2', 'PTPRQ', 'HECW2-AS1', 'ATRNL1', 'ADAMDEC1', 'SLC27A2', 'HAS1', 'UBASH3A', 'SYT4', 'GLYCTK', 'ERBB4', 'CTLA4', 'CHAC1', 'SNCG', 'TRIM55', 'CGN', 'MAL2', 'WAKMAR2', 'CES1', 'CTD-2297D10.2', 'ANKRD30A', 'FCRLA', 'CCND1', 'LEP', 'CETP', 'PLS1', 'CTD-2288O8.3', 'MSLN', 'MYO5B', 'METTL7B', 'KIF17', 'SLC39A8', 'BMPR1B', 'PMAIP1', 'TTC36', 'GRIP1', 'KRT7', 'UPK3B', 'PRG4', 'FAM160A1', 'ABCB11', 'SAA2', 'TNFRSF12A', 'CFB', 'LINC01235', 'KLHL30', 'KLF5', 'ZKSCAN7', 'PARD6B', 'HOXA10', 'SLC28A3', 'KRT18', 'HP', 'FCGBP', 'SERPINB2', 'PTPRZ1', 'APOB', 'SAA1', 'PLA2G2A', 'PCLO', 'CLDN1', 'LINC01617', 'WWC1', 'NELL2', 'PTCHD4', 'KLHL31', 'PRSS35'}
# ...

# %%
a = CrF_CD_set & CD_Con_set
print(CrF_Con_set & a)
print(len(CrF_Con_set & a))
# Out:
# {'FCRL2', 'IFNG-AS1', 'SLAMF7', 'JCHAIN', 'LINC02362', 'JSRP1', 'HLA-DOB', 'BHLHA15', 'DERL3', 'TNFRSF17', 'ITLN1', 'FCRL5', 'SDC1', 'AMPD1', 'MZB1', 'POU2AF1'}
# 16

# %% [markdown]
# 130  개의 gene이 CrF_Con 436에 포함 될 것인가?

# %%
print(len(CD_Con_set & CrF_Con_set))
print(CD_Con_set & CrF_Con_set)
# Out:
# 80
# {'ARHGDIG', 'IGF2BP3', 'DERL3', 'AADAC', 'GRIA1', 'CCL3', 'NQO1', 'TMIGD3', 'KRT8', 'LUZP2', 'FCRL2', 'ITGB2-AS1', 'ADAMTS14', 'CNTN3', 'ALPK2', 'DNAJC5B', 'HHIP', 'KIF19', 'TIMD4', 'CRYAB', 'APOE', 'PI15', 'SDC1', 'AMPD1', 'MZB1', 'FGF1', 'IFNG-AS1', 'SLPI', 'DEFB132', 'SPP1', 'GJC3', 'CTD-3247F14.2', 'HECW2-AS1', 'ATRNL1', 'ADAMDEC1', 'UBASH3A', 'ERBB4', 'CTLA4', 'SNCG', 'TRIM55', 'BHLHA15', 'MAL2', 'WAKMAR2', 'CES1', 'JCHAIN', 'FCRLA', 'HLA-DOB', 'CCND1', 'LEP', 'CETP', 'PLS1', 'METTL7B', 'KIF17', 'BMPR1B', 'FCRL5', 'PMAIP1', 'LINC02362', 'JSRP1', 'TTC36', 'PRG4', 'ABCB11', 'SAA2', 'TNFRSF12A', 'LINC01235', 'KLHL30', 'HOXA10', 'SLAMF7', 'ITLN1', 'KRT18', 'FCGBP', 'PTPRZ1', 'APOB', 'SAA1', 'PLA2G2A', 'PCLO', 'TNFRSF17', 'PTCHD4', 'KLHL31', 'PRSS35', 'POU2AF1'}

# %% [markdown]
# Nope

# %%
print(len(CD_Con_set - CrF_Con_set))
print(CD_Con_set - CrF_Con_set)
# Out:
# 50
# {'CHAC1', 'FAM160A1', 'CDCP1', 'CGN', 'UPK1B', 'CFB', 'KRT19', 'HOOK1', 'BICDL1', 'DSC3', 'FAT2', 'TMEM196', 'KLF5', 'ZKSCAN7', 'LGI1', 'PARD6B', 'SCEL', 'CTD-2297D10.2', 'MYRF', 'SLC28A3', 'CXADR', 'ANKRD30A', 'CDH1', 'COBL', 'HP', 'ALOX15', 'SERPINB2', 'RARRES1', 'CTD-2288O8.3', 'TGM1', 'MSLN', 'MYO5B', 'BNC1', 'GRIK1', 'SLC39A8', 'CLDN1', 'SERTM1', 'LINC01617', 'PTPRQ', 'ASPM', 'WWC1', 'FAM110C', 'NELL2', 'SLC27A2', 'HAS1', 'GRIP1', 'SYT4', 'GLYCTK', 'KRT7', 'UPK3B'}

# %%
print(len(CrF_Con_set - CD_Con_set))
print(CrF_Con_set - CD_Con_set)
# Out:
# 383
# ...

# %%
print(len(CrF_Con_set - CD_Con_set))
print(CrF_Con_set - CD_Con_set)

# %%
hap = CrF_CD_set & CrF_Con_set & CD_Con_set
hap
# Out:
# {'AMPD1',
#  'BHLHA15',
#  'DERL3',
#  'FCRL2',
#  'FCRL5',
#  'HLA-DOB',
#  'IFNG-AS1',
#  'ITLN1',
#  'JCHAIN',
#  'JSRP1',
#  'LINC02362',
#  'MZB1',
#  'POU2AF1',
#  'SDC1',
#  'SLAMF7',
#  'TNFRSF17'}

# %%
(CrF_CD_set & CD_Con_set) & hap
# Out:
# {'AMPD1',
#  'BHLHA15',
#  'DERL3',
#  'FCRL2',
#  'FCRL5',
#  'HLA-DOB',
#  'IFNG-AS1',
#  'ITLN1',
#  'JCHAIN',
#  'JSRP1',
#  'LINC02362',
#  'MZB1',
#  'POU2AF1',
#  'SDC1',
#  'SLAMF7',
#  'TNFRSF17'}

# %%
CD_Con_deg[CD_Con_deg['gene'].isin(list(CrF_CD_set & CD_Con_set))]['log2FoldChange']
# Out:
# 632     -1.861200
# 921      3.873401
# 1198     3.618256
# 1200     3.150245
# 1243     1.803942
# 1246    -5.518357
# 1468    -1.699123
# 1798    -3.566424
# 1875     3.057449
# 4350     3.258466
# 4769     2.347162
# 5334     3.044220
# 5941     1.968164
# 7049     2.170129
# 9887    -1.872677
# 10305    2.741770
# 11059    1.739586
# 11339   -2.057087
# 12879   -2.851707
# 13197    2.297091
# 13564   -2.483238
# 13838   -2.669933
# 14241   -3.171624
# 14905   -2.316855
# 15131    7.626088
# 16931    3.950486
# Name: log2FoldChange, dtype: float64

# %%
display(CD_Con_deg[['gene']])
display(CrF_Con_deg[['gene']])
display(CrF_CD_deg[['gene']])
# Out:
#             gene
# 211      PLA2G2A
# 224        KIF17
# 632        HOOK1
# 892       TMIGD3
# 921        AMPD1
# ...          ...
# 16681      CXADR
# 16718      GRIK1
# 16799    UBASH3A
# 16827  ITGB2-AS1
# 16931      DERL3
#
# [130 rows x 1 columns]
#              gene
# 10       TNFRSF18
# 11        TNFRSF4
# 21         TAS1R3
# 110    PIK3CD-AS2
# 115          RBP7
# ...           ...
# 16939     ADORA2A
# 16958        MIAT
# 17011        SMTN
# 17058       IL2RB
# 17148        MEI1
#
# [463 rows x 1 columns]
#                gene
# 174        ARHGEF19
# 260            CNR2
# 632           HOOK1
# 725          MCOLN2
# 876    RP11-284N8.3
# ...             ...
# 16410         SPAG4
# 16514          MMP9
# 16632       SLC17A9
# 16931         DERL3
# 17148          MEI1
#
# [101 rows x 1 columns]

# %%
plt.figure(figsize = (10,10))
plt.rc('ytick', labelsize=10)
sns.histplot(data=CD_Con_deg, 
            x='baseMean',
            bins=10, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            stat='percent', ## y값 계산 방식 count
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# <Axes: xlabel='baseMean', ylabel='Percent'>

# %%
plt.figure(figsize = (10,10))
plt.rc('ytick', labelsize=10)
sns.histplot(data=CD_Con_deg, 
            x='log2FoldChange',
            bins=50, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # stat='percent', ## y값 계산 방식 count
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# <Axes: xlabel='log2FoldChange', ylabel='Count'>

# %%
display(CD_Con_deg)
display(CrF_Con_deg)
display(CrF_CD_deg)
# Out:
#             gene    baseMean  log2FoldChange     lfcSE      stat  \
# 211      PLA2G2A  866.446798       -2.024622  0.536704 -3.772324
# 224        KIF17  110.263243        1.730023  0.372226  4.647780
# 632        HOOK1  181.203008       -1.861200  0.526293 -3.536433
# 892       TMIGD3  188.786092        1.882038  0.616226  3.054136
# 921        AMPD1  142.550962        3.873401  0.685011  5.654507
# ...          ...         ...             ...       ...       ...
# 16681      CXADR  202.719331       -2.681229  0.776112 -3.454691
# 16718      GRIK1  169.555954        1.521035  0.336923  4.514487
# 16799    UBASH3A  107.807700        1.524611  0.521420  2.923958
# 16827  ITGB2-AS1   59.035776        1.709851  0.566935  3.015954
# 16931      DERL3   67.764247        3.950486  0.840560  4.699826
#
#              pvalue      padj
# 211    1.617339e-04  0.004326
# 224    3.355261e-06  0.000285
# 632    4.055691e-04  0.008220
# 892    2.257100e-03  0.026354
# ...

# %%
print(len(CD_Con_deg[CD_Con_deg['log2FoldChange'] > 1.5]))
print(len(CD_Con_deg[CD_Con_deg['log2FoldChange'] < 1.5]))
# Out:
# 49
# 81

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CD_Con_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # stat='percent', ## y값 계산 방식 count
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\2968390867.py:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CD_Con_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_Con_deg[CrF_Con_deg['log2FoldChange'] > 1.5]))
print(len(CrF_Con_deg[CrF_Con_deg['log2FoldChange'] < 1.5]))
# Out:
# 327
# 136

# %%
plt.figure(figsize = (8,5))
# plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_Con_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # stat='percent', ## y값 계산 방식 count
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_CD_deg[CrF_CD_deg['log2FoldChange'] > 1.5]))
print(len(CrF_CD_deg[CrF_CD_deg['log2FoldChange'] < 1.5]))
# Out:
# 85
# 16

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_CD_deg, 
            x='log2FoldChange',
            bins=55, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # stat='percent', ## y값 계산 방식 count
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %% [markdown]
# ## log fold change > 1

# %%
CD_Con_lfc1_deg = CD_Con[(CD_Con['padj'] < 0.05) & (abs(CD_Con['log2FoldChange']) > 1)]
CrF_Con_lfc1_deg = CrF_Con[(CrF_Con['padj'] < 0.05) & (abs(CrF_Con['log2FoldChange']) > 1)]
CrF_CD_lfc1_deg = CrF_CD[(CrF_CD['padj'] < 0.05) & (abs(CrF_CD['log2FoldChange']) > 1)]

display(CD_Con_lfc1_deg)
display(CrF_Con_lfc1_deg)
display(CrF_CD_lfc1_deg)
# Out:
#             gene     baseMean  log2FoldChange     lfcSE      stat  \
# 115         RBP7  3461.896404        1.306983  0.207077  6.311568
# 172        HSPB7  1142.564118       -1.498729  0.470483 -3.185508
# 195      ALDH4A1  1551.026456       -1.219922  0.342144 -3.565524
# 211      PLA2G2A   866.446798       -2.024622  0.536704 -3.772324
# 212       PLA2G5   324.972185        1.039854  0.306414  3.393623
# ...          ...          ...             ...       ...       ...
# 16931      DERL3    67.764247        3.950486  0.840560  4.699826
# 16958       MIAT   372.985692        1.036770  0.267861  3.870550
# 16975      EMID1   219.306689        1.272182  0.357843  3.555141
# 17200  PRR34-AS1   126.630555       -1.100635  0.276140 -3.985790
# 17249      CPT1B   704.948407        1.089955  0.252945  4.309066
#
#              pvalue          padj
# 115    2.762232e-10  2.460976e-07
# 172    1.445000e-03  1.980622e-02
# 195    3.631303e-04  7.726004e-03
# ...

# %%
print(len(CD_Con_lfc1_deg[CD_Con_lfc1_deg['log2FoldChange'] > 1]))
print(len(CD_Con_lfc1_deg[CD_Con_lfc1_deg['log2FoldChange'] < 1]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CD_Con_lfc1_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 121
# 156
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\3355852096.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CD_Con_lfc1_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_Con_lfc1_deg[CrF_Con_lfc1_deg['log2FoldChange'] > 1]))
print(len(CrF_Con_lfc1_deg[CrF_Con_lfc1_deg['log2FoldChange'] < 1]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_Con_lfc1_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 612
# 336
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\2876083418.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CrF_Con_lfc1_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_CD_lfc1_deg[CrF_CD_lfc1_deg['log2FoldChange'] > 1]))
print(len(CrF_CD_lfc1_deg[CrF_CD_lfc1_deg['log2FoldChange'] < 1]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_CD_lfc1_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 236
# 61
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\1447049295.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CrF_CD_lfc1_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %% [markdown]
# ## log fold change > 1.2

# %%
CD_Con_lfc12_deg = CD_Con[(CD_Con['padj'] < 0.05) & (abs(CD_Con['log2FoldChange']) > 1.2)]
CrF_Con_lfc12_deg = CrF_Con[(CrF_Con['padj'] < 0.05) & (abs(CrF_Con['log2FoldChange']) > 1.2)]
CrF_CD_lfc12_deg = CrF_CD[(CrF_CD['padj'] < 0.05) & (abs(CrF_CD['log2FoldChange']) > 1.2)]

display(CD_Con_lfc12_deg)
display(CrF_Con_lfc12_deg)
display(CrF_CD_lfc12_deg)
# Out:
#             gene     baseMean  log2FoldChange     lfcSE      stat  \
# 115         RBP7  3461.896404        1.306983  0.207077  6.311568
# 172        HSPB7  1142.564118       -1.498729  0.470483 -3.185508
# 195      ALDH4A1  1551.026456       -1.219922  0.342144 -3.565524
# 211      PLA2G2A   866.446798       -2.024622  0.536704 -3.772324
# 224        KIF17   110.263243        1.730023  0.372226  4.647780
# ...          ...          ...             ...       ...       ...
# 16718      GRIK1   169.555954        1.521035  0.336923  4.514487
# 16799    UBASH3A   107.807700        1.524611  0.521420  2.923958
# 16827  ITGB2-AS1    59.035776        1.709851  0.566935  3.015954
# 16931      DERL3    67.764247        3.950486  0.840560  4.699826
# 16975      EMID1   219.306689        1.272182  0.357843  3.555141
#
#              pvalue          padj
# 115    2.762232e-10  2.460976e-07
# 172    1.445000e-03  1.980622e-02
# 195    3.631303e-04  7.726004e-03
# ...

# %%
print(len(CD_Con_lfc12_deg[CD_Con_lfc12_deg['log2FoldChange'] > 1.2]))
print(len(CD_Con_lfc12_deg[CD_Con_lfc12_deg['log2FoldChange'] < 1.2]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CD_Con_lfc12_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 79
# 116
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\2786122712.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CD_Con_lfc12_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_Con_lfc12_deg[CrF_Con_lfc12_deg['log2FoldChange'] > 1.2]))
print(len(CrF_Con_lfc12_deg[CrF_Con_lfc12_deg['log2FoldChange'] < 1.2]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_Con_lfc12_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 464
# 232
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\544452133.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CrF_Con_lfc12_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_CD_lfc12_deg[CrF_CD_lfc12_deg['log2FoldChange'] > 1.2]))
print(len(CrF_CD_lfc12_deg[CrF_CD_lfc12_deg['log2FoldChange'] < 1.2]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_CD_lfc12_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 155
# 33
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\4115998809.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CrF_CD_lfc12_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %% [markdown]
# ## log fold change > 2

# %%
CD_Con_lfc2_deg = CD_Con[(CD_Con['padj'] < 0.05) & (abs(CD_Con['log2FoldChange']) > 2)]
CrF_Con_lfc2_deg = CrF_Con[(CrF_Con['padj'] < 0.05) & (abs(CrF_Con['log2FoldChange']) > 2)]
CrF_CD_lfc2_deg = CrF_CD[(CrF_CD['padj'] < 0.05) & (abs(CrF_CD['log2FoldChange']) > 2)]

display(CD_Con_lfc2_deg)
display(CrF_Con_lfc2_deg)
display(CrF_CD_lfc2_deg)
print(len(CrF_CD_lfc2_deg))
# Out:
#           gene    baseMean  log2FoldChange     lfcSE      stat        pvalue  \
# 211    PLA2G2A  866.446798       -2.024622  0.536704 -3.772324  1.617339e-04
# 921      AMPD1  142.550962        3.873401  0.685011  5.654507  1.562943e-08
# 1069       CGN  169.971098       -3.102553  0.965796 -3.212430  1.316170e-03
# 1198     FCRL5  771.739057        3.618256  0.563836  6.417219  1.387866e-10
# 1200     FCRL2  144.460982        3.150245  0.882350  3.570289  3.565870e-04
# ...        ...         ...             ...       ...       ...           ...
# 15131    JSRP1   58.917549        7.626088  0.967796  7.879854  3.277633e-15
# 15734    FCGBP  146.514269       -2.292153  0.609815 -3.758769  1.707513e-04
# 16005     HAS1  678.436070       -2.432904  0.823573 -2.954086  3.135964e-03
# 16681    CXADR  202.719331       -2.681229  0.776112 -3.454691  5.509232e-04
# 16931    DERL3   67.764247        3.950486  0.840560  4.699826  2.603835e-06
#
#                padj
# 211    4.325546e-03
# ...

# %%
print(len(CD_Con_lfc2_deg[CD_Con_lfc2_deg['log2FoldChange'] > 2]))
print(len(CD_Con_lfc2_deg[CD_Con_lfc2_deg['log2FoldChange'] < 2]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CD_Con_lfc2_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\442407098.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CD_Con_lfc2_deg,
# 27
# 42
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_Con_lfc2_deg[CrF_Con_lfc2_deg['log2FoldChange'] > 2]))
print(len(CrF_Con_lfc2_deg[CrF_Con_lfc2_deg['log2FoldChange'] < 2]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_Con_lfc2_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 166
# 55
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\219653119.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CrF_Con_lfc2_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
print(len(CrF_CD_lfc2_deg[CrF_CD_lfc2_deg['log2FoldChange'] > 2]))
print(len(CrF_CD_lfc2_deg[CrF_CD_lfc2_deg['log2FoldChange'] < 2]))

plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.set_theme(style='whitegrid')
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=CrF_CD_lfc2_deg, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            palette='cool',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림)
)
# Out:
# 26
# 7
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\620625372.py:8: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=CrF_CD_lfc2_deg,
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %% [markdown]
# ---

# %%
lfc_1 = pd.DataFrame(columns=['LFC_value', 'log2foldchange'])
lfc_12 = pd.DataFrame(columns=['LFC_value', 'log2foldchange'])
lfc_05 = pd.DataFrame(columns=['LFC_value', 'log2foldchange'])
lfc_2 = pd.DataFrame(columns=['LFC_value', 'log2foldchange'])

# %%
display(CD_Con)
display(CrF_Con)
display(CrF_CD)
# Out:
#             gene     baseMean  log2FoldChange     lfcSE      stat    pvalue  \
# 0      LINC01409   171.584893       -0.215632  0.302521 -0.712785  0.475979
# 1         FAM87B    75.323918       -0.207557  0.435445 -0.476654  0.633608
# 2      LINC01128  1071.957048       -0.514346  0.183977 -2.795705  0.005179
# 3         SAMD11   107.906264       -0.922050  0.442539 -2.083545  0.037202
# 4          NOC2L   650.471727        0.069691  0.146395  0.476048  0.634040
# ...          ...          ...             ...       ...       ...       ...
# 17263    MT-ND4L   432.764866       -0.317473  0.236880 -1.340223  0.180173
# 17264     MT-ND4  1705.550426       -0.400741  0.166924 -2.400740  0.016362
# 17265     MT-ND5  1667.546508       -0.503011  0.160014 -3.143536  0.001669
# 17266     MT-ND6   126.476279       -0.510547  0.224731 -2.271811  0.023098
# 17267     MT-CYB  3868.999654       -0.287480  0.196699 -1.461519  0.143873
#
#            padj
# 0      0.720743
# 1      0.821876
# ...

# %%
CD_Con['type'] = 'CD vs Con'
CrF_Con['type'] = 'CrF vs Con'
CrF_CD['type'] = 'CrF vs CD'

# %%
_lfc = pd.concat([CD_Con, CrF_Con, CrF_CD])

# %%
lfc = _lfc[['log2FoldChange', 'padj', 'type']]

# %%
lfc
# Out:
#        log2FoldChange      padj       type
# 0           -0.215632  0.720743  CD vs Con
# 1           -0.207557  0.821876  CD vs Con
# 2           -0.514346  0.045810  CD vs Con
# 3           -0.922050  0.163122  CD vs Con
# 4            0.069691  0.822128  CD vs Con
# ...               ...       ...        ...
# 17263       -0.152106  0.642094  CrF vs CD
# 17264       -0.071293  0.773299  CrF vs CD
# 17265        0.060218  0.804179  CrF vs CD
# 17266        0.021963  0.954841  CrF vs CD
# 17267       -0.068336  0.821588  CrF vs CD
#
# [51804 rows x 3 columns]

# %%
lfc.type.value_counts()
# Out:
# CD vs Con     17268
# CrF vs Con    17268
# CrF vs CD     17268
# Name: type, dtype: int64

# %%
lfc_1 = lfc[(lfc['padj'] < 0.05) & (abs(lfc['log2FoldChange']) > 1)]
lfc_12 = lfc[(lfc['padj'] < 0.05) & (abs(lfc['log2FoldChange']) > 1.2)]
lfc_15 = lfc[(lfc['padj'] < 0.05) & (abs(lfc['log2FoldChange']) > 1.5)]
lfc_2 = lfc[(lfc['padj'] < 0.05) & (abs(lfc['log2FoldChange']) > 2)]

# %%
lfc_1['Threshold'] = 1.0
lfc_12['Threshold'] = 1.2
lfc_15['Threshold'] = 1.5
lfc_2['Threshold'] = 2.0
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\2100242955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lfc_1['Threshold'] = 1.0
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\2100242955.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lfc_12['Threshold'] = 1.2
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\2100242955.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
lfc_1[lfc_1['type'] == 'CD vs Con']
# Out:
#        log2FoldChange          padj       type  Threshold
# 115          1.306983  2.460976e-07  CD vs Con        1.0
# 172         -1.498729  1.980622e-02  CD vs Con        1.0
# 195         -1.219922  7.726004e-03  CD vs Con        1.0
# 211         -2.024622  4.325546e-03  CD vs Con        1.0
# 212          1.039854  1.209388e-02  CD vs Con        1.0
# ...               ...           ...        ...        ...
# 16931        3.950486  2.394688e-04  CD vs Con        1.0
# 16958        1.036770  3.252001e-03  CD vs Con        1.0
# 16975        1.272182  7.911351e-03  CD vs Con        1.0
# 17200       -1.100635  2.344095e-03  CD vs Con        1.0
# 17249        1.089955  8.445603e-04  CD vs Con        1.0
#
# [277 rows x 4 columns]

# %%
lfc_1_CDCon = pd.concat([lfc_1[lfc_1['type'] == 'CD vs Con'], lfc_12[lfc_12['type'] == 'CD vs Con'], lfc_15[lfc_15['type'] == 'CD vs Con'], lfc_2[lfc_2['type'] == 'CD vs Con']])
lfc_1_CDCon
# Out:
#        log2FoldChange          padj       type  Threshold
# 115          1.306983  2.460976e-07  CD vs Con        1.0
# 172         -1.498729  1.980622e-02  CD vs Con        1.0
# 195         -1.219922  7.726004e-03  CD vs Con        1.0
# 211         -2.024622  4.325546e-03  CD vs Con        1.0
# 212          1.039854  1.209388e-02  CD vs Con        1.0
# ...               ...           ...        ...        ...
# 15131        7.626088  1.557422e-11  CD vs Con        2.0
# 15734       -2.292153  4.494580e-03  CD vs Con        2.0
# 16005       -2.432904  3.294264e-02  CD vs Con        2.0
# 16681       -2.681229  1.031986e-02  CD vs Con        2.0
# 16931        3.950486  2.394688e-04  CD vs Con        2.0
#
# [671 rows x 4 columns]

# %%
lfc_1_CrFCon = pd.concat([lfc_1[lfc_1['type'] == 'CrF vs Con'], lfc_12[lfc_12['type'] == 'CrF vs Con'], lfc_15[lfc_15['type'] == 'CrF vs Con'], lfc_2[lfc_2['type'] == 'CrF vs Con']])
lfc_1_CrFCon
# Out:
#        log2FoldChange          padj        type  Threshold
# 3           -1.154033  4.422122e-02  CrF vs Con        1.0
# 10           2.263326  1.582782e-02  CrF vs Con        1.0
# 11           2.335945  1.524638e-04  CrF vs Con        1.0
# 21           2.946113  6.232738e-05  CrF vs Con        1.0
# 53           1.499470  2.780660e-02  CrF vs Con        1.0
# ...               ...           ...         ...        ...
# 16827        2.369000  5.383433e-04  CrF vs Con        2.0
# 16912       -3.214374  2.151176e-04  CrF vs Con        2.0
# 16931        5.739769  2.986735e-09  CrF vs Con        2.0
# 16958        2.243749  5.079107e-14  CrF vs Con        2.0
# 17148        2.703697  2.631121e-07  CrF vs Con        2.0
#
# [2328 rows x 4 columns]

# %%
lfc_1_CrFCD = pd.concat([lfc_1[lfc_1['type'] == 'CrF vs CD'], lfc_12[lfc_12['type'] == 'CrF vs CD'], lfc_15[lfc_15['type'] == 'CrF vs CD'], lfc_2[lfc_2['type'] == 'CrF vs CD']])
lfc_1_CrFCD
# Out:
#        log2FoldChange      padj       type  Threshold
# 21           1.436071  0.036501  CrF vs CD        1.0
# 53           1.358908  0.021313  CrF vs CD        1.0
# 174          1.545147  0.002401  CrF vs CD        1.0
# 231          1.071843  0.042494  CrF vs CD        1.0
# 260          2.227310  0.016969  CrF vs CD        1.0
# ...               ...       ...        ...        ...
# 14390        2.155260  0.011100  CrF vs CD        2.0
# 15198        2.062401  0.001421  CrF vs CD        2.0
# 15464        2.476275  0.009157  CrF vs CD        2.0
# 15780        3.191178  0.000030  CrF vs CD        2.0
# 16514        2.130957  0.005157  CrF vs CD        2.0
#
# [619 rows x 4 columns]

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_1_CDCon, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='Threshold',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_1_CrFCon, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='Threshold',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_1_CrFCD, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='Threshold',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
lfc_1_CDCon
# Out:
#        log2FoldChange          padj       type  Threshold
# 115          1.306983  2.460976e-07  CD vs Con        1.0
# 172         -1.498729  1.980622e-02  CD vs Con        1.0
# 195         -1.219922  7.726004e-03  CD vs Con        1.0
# 211         -2.024622  4.325546e-03  CD vs Con        1.0
# 212          1.039854  1.209388e-02  CD vs Con        1.0
# ...               ...           ...        ...        ...
# 15131        7.626088  1.557422e-11  CD vs Con        2.0
# 15734       -2.292153  4.494580e-03  CD vs Con        2.0
# 16005       -2.432904  3.294264e-02  CD vs Con        2.0
# 16681       -2.681229  1.031986e-02  CD vs Con        2.0
# 16931        3.950486  2.394688e-04  CD vs Con        2.0
#
# [671 rows x 4 columns]

# %%
plt.scatter(x=lfc_1_CDCon['log2FoldChange'],
            y=lfc_1_CDCon['padj'].apply(lambda x:-np.log10(x)),
            s=1,)

# %%
sns.scatterplot(data=lfc_1_CDCon,
                x=lfc_1_CDCon['log2FoldChange'],
                y=lfc_1_CDCon['padj'].apply(lambda x:-np.log10(x)),
                s=10,
                hue='Threshold')
# Out:
# <Axes: xlabel='log2FoldChange', ylabel='padj'>

# %%
sns.distplot(lfc_1[lfc_1['type'] == 'CD_Con']['log2FoldChange'], hist = False)
sns.distplot(lfc_1[lfc_1['type'] == 'CrF_Con']['log2FoldChange'], hist = False)
sns.distplot(lfc_1[lfc_1['type'] == 'CrF_CD']['log2FoldChange'], hist = False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\1141041351.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(lfc_1[lfc_1['type'] == 'CD_Con']['log2FoldChange'], hist = False)
# c:\Users\user\.conda\envs\ml\lib\site-packages\seaborn\distributions.py:2479: RuntimeWarning: Mean of empty slice.
#   line, = ax.plot(a.mean(), 0)
# c:\Users\user\.conda\envs\ml\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\user\AppData\Local\Temp\ipykernel_1656\1141041351.py:2: UserWarning:
#
# ...

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_1, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            # element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='type',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_12, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='type',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_15, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='type',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>

# %%
plt.figure(figsize = (8,5))
plt.rc('ytick', labelsize=10)
sns.color_palette("coolwarm", as_cmap=True)
plt.xlabel(r'$Log_2$ fold change')
sns.histplot(data=lfc_2, 
            x='log2FoldChange',
            bins=35, ## bin 개수
            kde=True, ## 밀도 함수 곡선 추가
            element='step', ## 히스토그램 표시형식,
            # palette='deep',
            hue='type',
            cumulative=False, ## True인 경우 누적 분포 형태로 그림),
)
# Out:
# <Axes: xlabel='$Log_2$ fold change', ylabel='Count'>
